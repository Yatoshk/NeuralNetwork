# %%
import tensorflow as tf
import tf2onnx

# %%
model = tf.keras.models.load_model('C:/Users/chesa/numbers_modelsv')

# %%
tf2onnx.convert.from_keras(model, output_path='model.onnx')
# Out:
# (ir_version: 8
#  producer_name: "tf2onnx"
#  producer_version: "1.14.0 8f8d49"
#  graph {
#    node {
#      input: "input_1"
#      input: "new_shape__27"
#      output: "model/conv2d/BiasAdd__6:0"
#      name: "model/conv2d/BiasAdd__6"
#      op_type: "Reshape"
#      domain: ""
#    }
#    node {
#      input: "model/conv2d/BiasAdd__6:0"
#      input: "model/conv2d/Conv2D/ReadVariableOp:0"
#      input: "model/conv2d/BiasAdd/ReadVariableOp:0"
#      output: "model/conv2d/BiasAdd:0"
#      name: "model/conv2d/BiasAdd"
#      op_type: "Conv"
#      attribute {
#        name: "dilations"
#        ints: 1
#        ints: 1
#        type: INTS
#      }
#      attribute {
#        name: "strides"
#        ints: 1
#        ints: 1
#        type: INTS
#      }
#      attribute {
#        name: "kernel_shape"
#        ints: 3
#        ints: 3
#        type: INTS
#      }
#      attribute {
#        name: "group"
#        i: 1
#        type: INT
#      }
#      domain: ""
#    }
# ...
